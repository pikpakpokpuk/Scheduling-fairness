# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)

beosztas = pd.read_csv('01_beosztas_2016_tavasz.csv')
beosztas[:10]
# Out:
#                             Unnamed: 0  Unnamed: 1    Idő  \
# 0  2016.06.15 (szerda)\nQB203\nVillany         1.0  08:40
# 1                                  NaN         2.0  09:20
# 2                                  NaN         3.0  10:30
# 3                                  NaN         4.0  11:20
# 4                                  NaN         5.0  12:10
# 5                                  NaN         6.0  14:50
# 6                                  NaN         7.0  15:00
# 7                                  NaN         8.0  15:40
# 8     2016.06.15 (szerda)\nQB205\nInfó         1.0  09:30
# 9                                  NaN         2.0  10:20
#
#                                Név  Képzés              Konzulens  \
# 0                     Németh Gábor  5-éves     Dr. Lengyel László
# 1                        Husi Géza     MSc            Oláh István
# 2                      Fehér Gábor     MSc            Futó András
# ...

# %%
beosztas.describe()
# Out:
#        Unnamed: 1  Külső konzulens
# count   98.000000              0.0
# mean     4.469388              NaN
# std      2.390721              NaN
# min      1.000000              NaN
# 25%      2.250000              NaN
# 50%      4.000000              NaN
# 75%      6.000000              NaN
# max     10.000000              NaN

# %%
beosztas.dtypes
# Out:
# Unnamed: 0          object
# Unnamed: 1         float64
# Idő                 object
# Név                 object
# Képzés              object
# Konzulens           object
# Külső konzulens    float64
# Vizsgatárgy         object
# Unnamed: 8          object
# Vizsgáztató         object
# Elnök               object
# Tag                 object
# Tag.1               object
# Titkár              object
# dtype: object

# %%
beosztas['Név']
# Out:
# 0                         Németh Gábor
# 1                            Husi Géza
# 2                          Fehér Gábor
# 3      Hencz Gábor Csaba (titkosított)
# 4                    Nguyen Khac Hoang
#                     ...
# 121                                NaN
# 122                                NaN
# 123                                NaN
# 124                                NaN
# 125                                NaN
# Name: Név, Length: 126, dtype: object

# %%
beosztas['Vizsgáztató']
# Out:
# 0                 Dr. Lengyel László
# 1      Bányász Gábor\nBenedek Zoltán
# 2      Bányász Gábor\nBenedek Zoltán
# 3      Bányász Gábor\nBenedek Zoltán
# 4      Benedek Zoltán\nBányász Gábor
#                    ...
# 121                              NaN
# 122                              NaN
# 123                              NaN
# 124                              NaN
# 125                              NaN
# Name: Vizsgáztató, Length: 126, dtype: object

# %%
beosztas['Vizsgáztató'].value_counts()
# Out:
# Dr. Dudás Ákos                                10
# Dr. Charaf Hassan\nDr. Charaf Hassan           5
# Bányász Gábor\nBenedek Zoltán                  5
# Dr. Lengyel László\nDr. Lengyel László         5
# Dr. Charaf Hassan\nDr. Forstner Bertalan       4
# Dr. Forstner Bertalan\nDr. Lengyel László      4
# Dr. Tevesz Gábor                               4
# Szabó Zoltán                                   3
# Gincsai Gábor                                  3
# Dr. Asztalos Márk\nDr. Mezei Gergely           3
# Benedek Zoltán\nSzabó Zoltán                   3
# Dr. Forstner Bertalan\nDr. Charaf Hassan       3
# Cserkúti Péter\nDr. Gál Tibor                  2
# Kiss Domonkos\nCserkúti Péter                  2
# Dr. Mezei Gergely\nDr. Forstner Bertalan       2
# Albert István                                  2
# Dr. Gál Tibor\nCserkúti Péter                  2
# Dr. Asztalos Márk                              2
# Kiss Domonkos                                  2
# ...

# %%
[row.split('\n') for row in beosztas['Vizsgáztató']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21704/2315864438.py in <module>
# ----> 1 [row.split('\n') for row in beosztas['Vizsgáztató']]
#
# ~\AppData\Local\Temp/ipykernel_21704/2315864438.py in <listcomp>(.0)
# ----> 1 [row.split('\n') for row in beosztas['Vizsgáztató']]
#
# AttributeError: 'float' object has no attribute 'split'
